# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

data = pd.read_csv('~/data/Germany_time_zone/all/train_with_all.csv', parse_dates=['ds'])
data = data.set_index('ds').sort_index()


# List the target columns you want to forecast
target_columns = ['renewable', 'non_renewable', 'cross_border_trading']

# Create naive forecast columns for each target column
for col in target_columns:
    data[f'{col}_yesterday']   = data[col].shift(24)
    data[f'{col}_last_week']   = data[col].shift(24 * 7)
    data[f'{col}_last_month']  = data[col].shift(24 * 30)  # approximate 30 days

# Evaluate each target's forecast performance
for col in target_columns:
    # For each target, drop rows where the actual or any forecast value is missing
    df = data.dropna(subset=[col, f'{col}_yesterday', f'{col}_last_week', f'{col}_last_month'])
    
    # Extract actual values and forecasts
    y_actual = df[col]
    y_yesterday = df[f'{col}_yesterday']
    y_last_week = df[f'{col}_last_week']
    y_last_month = df[f'{col}_last_month']
    
    # Compute errors for the yesterday baseline
    mae_yesterday = mean_absolute_error(y_actual, y_yesterday)
    mape_yesterday = mean_absolute_percentage_error(y_actual, y_yesterday)
    
    # Compute errors for the last-week baseline
    mae_last_week = mean_absolute_error(y_actual, y_last_week)
    mape_last_week = mean_absolute_percentage_error(y_actual, y_last_week)
    
    # Compute errors for the last-month baseline
    mae_last_month = mean_absolute_error(y_actual, y_last_month)
    mape_last_month = mean_absolute_percentage_error(y_actual, y_last_month)
    
    # Print the results for the current target
    print(f"Forecasting results for '{col}':")
    print(f"  Yesterday baseline:  MAE = {mae_yesterday:.2f},  MAPE = {mape_yesterday:.2%}")
    print(f"  Last-week baseline:  MAE = {mae_last_week:.2f},  MAPE = {mape_last_week:.2%}")
    print(f"  Last-month baseline: MAE = {mae_last_month:.2f},  MAPE = {mape_last_month:.2%}\n")
# Out:
# Forecasting results for 'renewable':
#   Yesterday baseline:  MAE = 7190.78,  MAPE = 30.58%
#   Last-week baseline:  MAE = 10025.84,  MAPE = 43.74%
#   Last-month baseline: MAE = 10762.14,  MAPE = 47.22%
#
# Forecasting results for 'non_renewable':
#   Yesterday baseline:  MAE = 4213.39,  MAPE = 21.04%
#   Last-week baseline:  MAE = 6026.55,  MAPE = 29.80%
#   Last-month baseline: MAE = 8865.65,  MAPE = 46.11%
#
# Forecasting results for 'cross_border_trading':
#   Yesterday baseline:  MAE = 3710.96,  MAPE = 565.34%
#   Last-week baseline:  MAE = 4366.62,  MAPE = 742.39%
#   Last-month baseline: MAE = 4999.03,  MAPE = 999.05%

# %%
data.head()
# Out:
#                          y           unique_id  day_of_week  month  hour  \
# ds
# 2018-10-01 00:00:00  59.53  electricity_prices            0     10     0
# 2018-10-01 01:00:00  56.10  electricity_prices            0     10     1
# 2018-10-01 02:00:00  51.41  electricity_prices            0     10     2
# 2018-10-01 03:00:00  47.38  electricity_prices            0     10     3
# 2018-10-01 04:00:00  47.59  electricity_prices            0     10     4
#
#                      is_weekend  is_holiday  month_sin  month_cos  \
# ds
# 2018-10-01 00:00:00           0           0  -0.866025        0.5
# 2018-10-01 01:00:00           0           0  -0.866025        0.5
# 2018-10-01 02:00:00           0           0  -0.866025        0.5
# 2018-10-01 03:00:00           0           0  -0.866025        0.5
# 2018-10-01 04:00:00           0           0  -0.866025        0.5
#
#                      day_of_week_sin  ...  synthetic_price  \
# ds                                    ...
# 2018-10-01 00:00:00              0.0  ...        55.530909
# 2018-10-01 01:00:00              0.0  ...        55.530909
# 2018-10-01 02:00:00              0.0  ...        55.530909
# 2018-10-01 03:00:00              0.0  ...        55.530909
# 2018-10-01 04:00:00              0.0  ...        55.530909
#
#                      renewable_yesterday  renewable_last_week  \
# ds
# 2018-10-01 00:00:00                  NaN                  NaN
# 2018-10-01 01:00:00                  NaN                  NaN
# 2018-10-01 02:00:00                  NaN                  NaN
# 2018-10-01 03:00:00                  NaN                  NaN
# 2018-10-01 04:00:00                  NaN                  NaN
#
#                      renewable_last_month  non_renewable_yesterday  \
# ds
# 2018-10-01 00:00:00                   NaN                      NaN
# 2018-10-01 01:00:00                   NaN                      NaN
# 2018-10-01 02:00:00                   NaN                      NaN
# 2018-10-01 03:00:00                   NaN                      NaN
# 2018-10-01 04:00:00                   NaN                      NaN
#
#                      non_renewable_last_week  non_renewable_last_month  \
# ds
# 2018-10-01 00:00:00                      NaN                       NaN
# 2018-10-01 01:00:00                      NaN                       NaN
# 2018-10-01 02:00:00                      NaN                       NaN
# 2018-10-01 03:00:00                      NaN                       NaN
# 2018-10-01 04:00:00                      NaN                       NaN
#
#                      cross_border_trading_yesterday  \
# ds
# 2018-10-01 00:00:00                             NaN
# 2018-10-01 01:00:00                             NaN
# 2018-10-01 02:00:00                             NaN
# 2018-10-01 03:00:00                             NaN
# 2018-10-01 04:00:00                             NaN
#
#                      cross_border_trading_last_week  \
# ds
# 2018-10-01 00:00:00                             NaN
# 2018-10-01 01:00:00                             NaN
# 2018-10-01 02:00:00                             NaN
# 2018-10-01 03:00:00                             NaN
# 2018-10-01 04:00:00                             NaN
#
#                      cross_border_trading_last_month
# ds
# 2018-10-01 00:00:00                              NaN
# 2018-10-01 01:00:00                              NaN
# 2018-10-01 02:00:00                              NaN
# 2018-10-01 03:00:00                              NaN
# 2018-10-01 04:00:00                              NaN
#
# [5 rows x 29 columns]
